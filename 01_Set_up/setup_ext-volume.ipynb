# %%
# %sql

USE CATALOG ecommerce__;                     
CREATE SCHEMA IF NOT EXISTS raw;
CREATE EXTERNAL VOLUME IF NOT EXISTS raw.raw_landing
  LOCATION 's3://ecomm-raw-data-001/historical-full-load'
  COMMENT 'Raw ADLS Gen2 landing for ecommerce';
